# %% [markdown]
# # 6.2.2 Linear Discriminant Analysis (LDA)
#
# Linear Discriminant Analysis (LDA) is a technique used for classification and dimensionality reduction in supervised learning. It aims to find the linear combinations of features that best separate different classes.
# ___
# ___
# ### Readings:
# - [A Geometric Intuition for Linear Discriminant Analysis](https://omarshehata.github.io/lda-explorable/)
# - [Linear Discriminant Analysis – Bit by Bit](https://sebastianraschka.com/Articles/2014_python_lda.html)
# - [Dimensionality Reduction(PCA and LDA)](https://medium.com/machine-learning-researcher/dimensionality-reduction-pca-and-lda-6be91734f567)
# ___
# ___
# ### **Steps to perform LDA**:
# 1. **Standardize the Data**: Ensure the data has a mean of 0 and a standard deviation of 1.
# 2. **Compute the LDA Components**: Find the linear combinations of features that best separate the classes.
# 3. **Transform the Data**: Project the original data onto these components.
# 4. **Visualize the Results**: Plot the low-dimensional representation of the data.
#
# In this example, we will apply LDA to the Iris dataset to visualize its structure in 2D.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

# %%
# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Plot the original data in 3D
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
for target, color, label in zip(np.unique(y), ['r', 'g', 'b'], target_names):
    ax.scatter(X_scaled[y == target, 0], X_scaled[y == target, 1], X_scaled[y == target, 2], color=color, label=label, alpha=0.5)
plt.title('Original Iris Data (3D)')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Feature 3')
ax.legend()
plt.show()

# %%
# Apply LDA to reduce to 2D
lda = LinearDiscriminantAnalysis(n_components=2)
X_lda = lda.fit_transform(X_scaled, y)

# %%
# Plot the transformed data
plt.figure(figsize=(10, 6))
for target, color, label in zip(np.unique(y), ['r', 'g', 'b'], target_names):
    plt.scatter(X_lda[y == target, 0], X_lda[y == target, 1], color=color, label=label, alpha=0.5)
plt.title('Iris Data after LDA (2D)')
plt.xlabel('LDA Component 1')
plt.ylabel('LDA Component 2')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Explained variance ratio
explained_variance = lda.explained_variance_ratio_
print(f'Explained variance by LDA Component 1: {explained_variance[0]:.2f}')
print(f'Explained variance by LDA Component 2: {explained_variance[1]:.2f}')
# Out:
# Explained variance by LDA Component 1: 0.99
# Explained variance by LDA Component 2: 0.01

# %% [markdown]
# ## Conclusion
#
# In this example, we applied LDA to the Iris dataset to reduce its dimensionality and visualize its structure in 2D. The results illustrate how LDA focuses on finding the linear combinations of features that best separate the classes.
#
# ### Key points:
# - **Dimensionality Reduction**: LDA effectively reduced the data to 2 dimensions.
# - **Class Separation**: LDA focuses on finding the linear combinations of features that best separate the different classes.
# - **Data Visualization**: We visualized the transformed data, showing distinct clusters corresponding to the different Iris species.
#
# LDA is a valuable tool for both classification and dimensionality reduction, providing insights into the relationships between different classes in the dataset.
